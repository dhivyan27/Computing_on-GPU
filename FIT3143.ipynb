# %%
# !./POC
# Out:
# Streaming output truncated to the last 5000 lines.
# Element 45003: Non-Fused = 1.994613, Fused = 1.994613
# Element 45004: Non-Fused = 1.839081, Fused = 1.839081
# Element 45005: Non-Fused = 2.522096, Fused = 2.522096
# Element 45006: Non-Fused = 2.030237, Fused = 2.030237
# Element 45007: Non-Fused = 0.808779, Fused = 0.808779
# Element 45008: Non-Fused = 1.303496, Fused = 1.303496
# Element 45009: Non-Fused = 3.350939, Fused = 3.350939
# Element 45010: Non-Fused = 2.028177, Fused = 2.028177
# Element 45011: Non-Fused = 2.263838, Fused = 2.263838
# Element 45012: Non-Fused = 1.175195, Fused = 1.175195
# Element 45013: Non-Fused = 3.323225, Fused = 3.323225
# Element 45014: Non-Fused = 2.584703, Fused = 2.584703
# Element 45015: Non-Fused = 1.919566, Fused = 1.919566
# Element 45016: Non-Fused = 0.469555, Fused = 0.469555
# Element 45017: Non-Fused = 1.187574, Fused = 1.187574
# Element 45018: Non-Fused = 2.919247, Fused = 2.919247
# ...

# %%
cd drive/MyDrive/Colab_Notebooks/
# Out:
# /content/drive/MyDrive/Colab_Notebooks

# %%
# !ls -l /dev/nv*
# Out:
# crw-rw-rw- 1 root root 195,   0 Nov  3 03:04 /dev/nvidia0
# crw-rw-rw- 1 root root 195, 255 Nov  3 03:04 /dev/nvidiactl
# crw-rw-rw- 1 root root 242,   0 Nov  3 03:04 /dev/nvidia-uvm
# crw-rw-rw- 1 root root 242,   1 Nov  3 03:04 /dev/nvidia-uvm-tools
#
# /dev/nvidia-caps:
# total 0
# cr-------- 1 root root 245, 1 Nov  3 03:04 nvidia-cap1
# cr--r--r-- 1 root root 245, 2 Nov  3 03:04 nvidia-cap2

# %%
# !nvcc POC.cu -o POC
